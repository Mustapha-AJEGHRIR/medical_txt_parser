# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mustapha-AJEGHRIR/medical_txt_parser/blob/main/src/notebooks/assertions_nli/ast_nli_scibert.ipynb)

# %% [markdown]
# # Prepare RE dataset
# scibert: https://raw.githubusercontent.com/allenai/scibert/master/data/text_classification/chemprot/train.txt
#
# scifive: https://github.com/justinphan3110/SciFive

# %%
# %%capture
# !pip install seqeval transformers datasets spacy sentence_transformers

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/projects/medical_txt_parser

# %%
# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

path = %pwd
while "src" in path:
    # %cd ..
    path = %pwd

import glob
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
from pprint import pprint
import matplotlib.pyplot as plt
import re

import transformers
from datasets import Dataset, ClassLabel, Sequence, load_dataset, load_metric
from spacy import displacy

assert transformers.__version__ >= "4.11.0"

from src.utils.parse_data import parse_ast, parse_concept, parse_relation

# %%
train_data_path = "data/train"
val_data_path = "data/val"
ast_folder_name = "ast"
concept_folder_name = "concept"
rel_folder_name = "rel"
txt_folder_name = "txt"
re_data_path = "data/re"
os.makedirs(re_data_path, exist_ok=True)

# %% [markdown]
# ### Import data

# %%
text_files = glob.glob(train_data_path + os.sep + txt_folder_name + os.sep +  "*.txt")
filename = ""
df = pd.DataFrame()
for file in tqdm(text_files):
    with open(file, 'r') as f:
        text = f.read()
        filename = file.split("/")[-1].split(".")[0]
        concept = parse_concept(train_data_path + os.sep + concept_folder_name + os.sep +  filename + ".con")
        rel = parse_relation(train_data_path + os.sep + rel_folder_name + os.sep +  filename + ".rel")
        
        df = df.append(pd.DataFrame({"text": [text], "filename": [filename] , "concept": [concept], "rel":[rel]}), ignore_index=True)
df.head()
# Out:
# 100%|██████████| 170/170 [00:00<00:00, 463.57it/s]
#                                                 text      filename  \
# 0  143748600 SC\n43243309\n095342\n09/30/2000 12:...  143748600_SC
# 1  Admission Date :\n2014-03-31\nDischarge Date :...     record-56
# 2  699905656 SC\n06100044\n921737\n1/17/1993 12:0...  699905656_SC
# 3  627258104\nGH\n56900479\n1/8/2001 12:00:00 AM\...     627258104
# 4  839999049 YC\n59242403\n431924\n11/01/2000 12:...  839999049_YC
#
#                                              concept  \
# 0  {'concept_text': ['htn', 'atypical chest pain'...
# 1  {'concept_text': ['the procedure', 'auscultati...
# 2  {'concept_text': ['right sided sciatica proced...
# 3  {'concept_text': ['bradycardia', 'subsequent f...
# 4  {'concept_text': ['pauses', 'outpt fitting', '...
#
#                                                  rel
# 0  {'concept_text_1': ['dm type ii', 'lead placem...
# 1  {'concept_text_1': ['ultrasound', 'ultrasound'...
# 2  {'concept_text_1': ['ct myelogram', 'ct myelog...
# 3  {'concept_text_1': ['bradycardia', 'a chest xr...
# 4  {'concept_text_1': ['ett', 'desaturations in t...

# %%
concept_df = pd.DataFrame(columns=[ "filename"]+list(concept.keys()))
for i, file in df.iterrows():
    concept_dict = file["concept"]
    tmp = pd.DataFrame(concept_dict)
    tmp["filename"] = file["filename"]
    concept_df = concept_df.append(tmp, ignore_index=True)
concept_df
# Out:
#            filename                   concept_text start_line  \
# 0      143748600_SC                            htn         52
# 1      143748600_SC            atypical chest pain          5
# 2      143748600_SC   wellbutrin ( bupropion hcl )         33
# 3      143748600_SC                            ett         58
# 4      143748600_SC                     dissection         56
# ...             ...                            ...        ...
# 16520     105732749  repeated fleet &apos;s enemas         53
# 16521     105732749                         biopsy         23
# 16522     105732749                   respirations         39
# 16523     105732749                    these tests         61
# 16524     105732749             abdominal cramping         52
#
#       start_word_number end_line end_word_number concept_type
# 0                    19       52              19      problem
# 1                     0        5               2      problem
# 2                    19       33              23    treatment
# 3                     3       58               3         test
# 4                     7       56               7      problem
# ...                 ...      ...             ...          ...
# 16520                 4       53               7    treatment
# 16521                 2       23               2         test
# 16522                 9       39               9         test
# 16523                11       61              12         test
# 16524                11       52              12      problem
#
# [16525 rows x 7 columns]

# %%
# add concepts
all_rel_df = pd.DataFrame()
for fname in tqdm(df["filename"].unique()):
    concept_dict = parse_concept(train_data_path + os.sep + concept_folder_name + os.sep + fname + ".con")
    
    concept_df = pd.DataFrame(concept_dict).drop(columns=["end_line"])
    test_concept_df = concept_df[concept_df["concept_type"] == "test"]
    problem_concept_df = concept_df[concept_df["concept_type"] == "problem"]
    treatment_concept_df = concept_df[concept_df["concept_type"] == "treatment"]

    # class test --> problem
    test_problem_df = pd.merge(test_concept_df, problem_concept_df, how="inner", on="start_line", suffixes=("_1", "_2"))

    # class treatment --> problem
    treatment_problem_df = pd.merge(treatment_concept_df, problem_concept_df, how="inner", on="start_line", suffixes=("_1", "_2"))

    # class problem --> problem
    problem_problem_df = pd.merge(problem_concept_df, problem_concept_df, how="inner", on="start_line", suffixes=("_1", "_2"))
    problem_problem_df = problem_problem_df[problem_problem_df["concept_text_1"] != problem_problem_df["concept_text_2"]] # TODO: remove duplicates ?

    tmp = pd.concat([test_problem_df, treatment_problem_df, problem_problem_df], axis=0)
    tmp["filename"] = fname
    all_rel_df = all_rel_df.append(tmp, ignore_index=True)
            
all_rel_df = all_rel_df.sort_values(by=["filename", "start_line"])
all_rel_df = all_rel_df.reset_index(drop=True)

all_rel_df
# Out:
# 100%|██████████| 170/170 [00:01<00:00, 90.12it/s]
#                      concept_text_1  start_line  start_word_number_1  \
# 0              c5-6 disc herniation        21.0                  0.0
# 1              c5-6 disc herniation        21.0                  0.0
# 2                  cord compression        21.0                  4.0
# 3                  cord compression        21.0                  4.0
# 4                        myelopathy        21.0                  7.0
# ...                             ...         ...                  ...
# 15338                      pressure        99.0                 23.0
# 15339           shortness of breath        99.0                 25.0
# 15340           shortness of breath        99.0                 25.0
# 15341  a transdermal nicotine patch       100.0                 34.0
# 15342                          rest       100.0                 13.0
#
#        end_word_number_1 concept_type_1        concept_text_2  \
# 0                    2.0        problem      cord compression
# 1                    2.0        problem            myelopathy
# 2                    5.0        problem  c5-6 disc herniation
# 3                    5.0        problem            myelopathy
# 4                    7.0        problem  c5-6 disc herniation
# ...                  ...            ...                   ...
# 15338               23.0        problem   shortness of breath
# 15339               27.0        problem            chest pain
# 15340               27.0        problem              pressure
# 15341               37.0      treatment              cravings
# 15342               13.0      treatment              cravings
#
#        start_word_number_2  end_word_number_2 concept_type_2      filename
# 0                      4.0                5.0        problem  018636330_DH
# 1                      7.0                7.0        problem  018636330_DH
# 2                      0.0                2.0        problem  018636330_DH
# 3                      7.0                7.0        problem  018636330_DH
# 4                      0.0                2.0        problem  018636330_DH
# ...                    ...                ...            ...           ...
# 15338                 25.0               27.0        problem     record-84
# 15339                 20.0               21.0        problem     record-84
# 15340                 23.0               23.0        problem     record-84
# 15341                 49.0               49.0        problem     record-84
# 15342                 49.0               49.0        problem     record-84
#
# [15343 rows x 10 columns]

# %%
rel_df = pd.DataFrame(columns=[ "filename"]+list(rel.keys()))
for i, file in df.iterrows():
    rel_dict = file["rel"]
    tmp = pd.DataFrame(rel_dict)
    tmp["filename"] = file["filename"]
    rel_df = rel_df.append(tmp, ignore_index=True)
rel_df.drop(columns=["end_line_1", "start_line_2", "end_line_2"], inplace=True)
rel_df.rename(columns={"start_line_1": "start_line"}, inplace=True)
rel_df
# Out:
#           filename                              concept_text_1 start_line  \
# 0     143748600_SC                                  dm type ii         52
# 1     143748600_SC                              lead placement         55
# 2     143748600_SC  t wave flattening laterally and inferiorly         55
# 3     143748600_SC                                    chest ct         56
# 4     143748600_SC                                    chest ct         56
# ...            ...                                         ...        ...
# 3115     105732749                                   a ct scan         27
# 3116     105732749                                    percocet         58
# 3117     105732749                                   specimens         48
# 3118     105732749                               the procedure         49
# 3119     105732749                                      repair         30
#
#      start_word_number_1 end_word_number_1        concept_text_2  \
# 0                      6                 8                  crfs
# 1                     20                21                  pain
# 2                      3                 8                  pain
# 3                      1                 2             back pain
# 4                      1                 2            dissection
# ...                  ...               ...                   ...
# 3115                  18                20                a mass
# 3116                   0                 0                  pain
# 3117                   0                 0     falciform nodules
# 3118                   9                10         complications
# 3119                  11                11  a ureteral stricture
#
#      start_word_number_2 end_word_number_2 relation_type
# 0                      4                 4           PIP
# 1                     10                10          TeRP
# 2                     10                10           PIP
# 3                     11                12          TeCP
# 4                      7                 7          TeCP
# ...                  ...               ...           ...
# 3115                  24                25          TeRP
# 3116                  12                12          TrAP
# 3117                  14                15          TeCP
# 3118                   3                 3          TrCP
# 3119                  13                15          TrAP
#
# [3120 rows x 9 columns]

# %%
# merge rel_df and all_rel_df
rel_df = pd.merge(all_rel_df, rel_df, how="left", on=["filename", "start_line", "start_word_number_1", "end_word_number_1", "start_word_number_2", "end_word_number_2", "concept_text_1", "concept_text_2"], suffixes=("_1", "_2"))

# set NaN to other
rel_df.fillna("Other", inplace=True)
# change float to int cols
for col in ["start_line", "start_word_number_1", "end_word_number_1", "start_word_number_2", "end_word_number_2"]:
    rel_df[col] = rel_df[col].astype(int)
rel_df
# Out:
#                      concept_text_1  start_line  start_word_number_1  \
# 0              c5-6 disc herniation          21                    0
# 1              c5-6 disc herniation          21                    0
# 2                  cord compression          21                    4
# 3                  cord compression          21                    4
# 4                        myelopathy          21                    7
# ...                             ...         ...                  ...
# 15338                      pressure          99                   23
# 15339           shortness of breath          99                   25
# 15340           shortness of breath          99                   25
# 15341  a transdermal nicotine patch         100                   34
# 15342                          rest         100                   13
#
#        end_word_number_1 concept_type_1        concept_text_2  \
# 0                      2        problem      cord compression
# 1                      2        problem            myelopathy
# 2                      5        problem  c5-6 disc herniation
# 3                      5        problem            myelopathy
# 4                      7        problem  c5-6 disc herniation
# ...                  ...            ...                   ...
# 15338                 23        problem   shortness of breath
# 15339                 27        problem            chest pain
# 15340                 27        problem              pressure
# 15341                 37      treatment              cravings
# 15342                 13      treatment              cravings
#
#        start_word_number_2  end_word_number_2 concept_type_2      filename  \
# 0                        4                  5        problem  018636330_DH
# 1                        7                  7        problem  018636330_DH
# 2                        0                  2        problem  018636330_DH
# 3                        7                  7        problem  018636330_DH
# 4                        0                  2        problem  018636330_DH
# ...                    ...                ...            ...           ...
# 15338                   25                 27        problem     record-84
# 15339                   20                 21        problem     record-84
# 15340                   23                 23        problem     record-84
# 15341                   49                 49        problem     record-84
# 15342                   49                 49        problem     record-84
#
#       relation_type
# 0               PIP
# 1               PIP
# 2             Other
# 3             Other
# 4             Other
# ...             ...
# 15338         Other
# 15339         Other
# 15340         Other
# 15341          TrAP
# 15342         Other
#
# [15343 rows x 11 columns]

# %%
rel_df["relation_type"].value_counts()
# Out:
# Other    12225
# TeRP       992
# TrAP       884
# PIP        755
# TrCP       184
# TeCP       166
# TrNAP       62
# TrIP        51
# TrWP        24
# Name: relation_type, dtype: int64

# %% [markdown]
# some relations don't exist in concept files. (Will ignore those)

# %%
# find difference between rel_df and new_rel_df
# difference_df = pd.merge(new_rel_df, rel_df, how="right", on=["filename", "start_line", "start_word_number_1", "end_word_number_1", "start_word_number_2", "end_word_number_2", "concept_text_1", "concept_text_2"], suffixes=("_1", "_2"))
# difference_df[difference_df.isnull().any(axis=1)]
# Out:
#      concept_text_1 start_line start_word_number_1 end_word_number_1  \
# 1390            asa         74                   0                 0
# 1879       percocet         85                   5                 5
#
#      concept_type_1 concept_text_2 start_word_number_2 end_word_number_2  \
# 1390            NaN      tricyclic                  15                15
# 1879            NaN    pain relief                   8                 9
#
#      concept_type_2    filename relation_type_1 relation_type_2
# 1390            NaN  record-177             NaN            TeRP
# 1879            NaN   record-18             NaN            TrAP

# %%
def preprocess_text(row):
    text = row["text"]
    # find line
    # text = text.lower()
    line = text.split("\n")[row["start_line"]-1]
    line = " ".join(line.split()) # remove multiple spaces

    concept_text_1 = "<< "+ " ".join(line.split()[row["start_word_number_1"]:row["end_word_number_1"]+1]) + " >>"
    concept_text_2 = "[[ " + " ".join(line.split()[row["start_word_number_2"]:row["end_word_number_2"]+1]) + " ]]"
    start_word_number_1 = row["start_word_number_1"]
    end_word_number_1 = row["end_word_number_1"]
    start_word_number_2 = row["start_word_number_2"]
    end_word_number_2 = row["end_word_number_2"]

    if row["start_word_number_1"] > row["start_word_number_2"]:
        concept_text_1, concept_text_2 = concept_text_2, concept_text_1
        start_word_number_1, start_word_number_2 = start_word_number_2, start_word_number_1
        end_word_number_1, end_word_number_2 = end_word_number_2, end_word_number_1
    text = " ".join(line.split()[: start_word_number_1] + [concept_text_1] + line.split()[end_word_number_1+1: start_word_number_2] + [concept_text_2] + line.split()[end_word_number_2+1:])

    row["text"] = text
    return row

rel_df = rel_df.merge(df[["filename","text"]], on="filename", how="inner")
rel_df = rel_df.apply(preprocess_text, axis=1)
rel_df = rel_df[["filename","start_line", "text", "concept_text_1", "concept_text_2", "relation_type", "concept_type_1", "concept_type_2"]]
rel_df.columns = ["filename","line_num", "text", "concept_text_1", "concept_text_2", "rel_type", "concept_type_1", "concept_type_2"]
rel_df
# Out:
#            filename  line_num  \
# 0      018636330_DH        21
# 1      018636330_DH        21
# 2      018636330_DH        21
# 3      018636330_DH        21
# 4      018636330_DH        21
# ...             ...       ...
# 15338     record-84        99
# 15339     record-84        99
# 15340     record-84        99
# 15341     record-84       100
# 15342     record-84       100
#
#                                                     text  \
# 0      << C5-6 disc herniation >> with [[ cord compre...
# 1      << C5-6 disc herniation >> with cord compressi...
# 2      [[ C5-6 disc herniation ]] with << cord compre...
# 3      C5-6 disc herniation with << cord compression ...
# 4      [[ C5-6 disc herniation ]] with cord compressi...
# ...                                                  ...
# 15338  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15339  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15340  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15341  The patient was told he could return to work a...
# 15342  The patient was told he could return to work a...
#
#                      concept_text_1        concept_text_2 rel_type  \
# 0              c5-6 disc herniation      cord compression      PIP
# 1              c5-6 disc herniation            myelopathy      PIP
# 2                  cord compression  c5-6 disc herniation    Other
# 3                  cord compression            myelopathy    Other
# 4                        myelopathy  c5-6 disc herniation    Other
# ...                             ...                   ...      ...
# 15338                      pressure   shortness of breath    Other
# 15339           shortness of breath            chest pain    Other
# 15340           shortness of breath              pressure    Other
# 15341  a transdermal nicotine patch              cravings     TrAP
# 15342                          rest              cravings    Other
#
#       concept_type_1 concept_type_2
# 0            problem        problem
# 1            problem        problem
# 2            problem        problem
# 3            problem        problem
# 4            problem        problem
# ...              ...            ...
# 15338        problem        problem
# 15339        problem        problem
# 15340        problem        problem
# 15341      treatment        problem
# 15342      treatment        problem
#
# [15343 rows x 8 columns]

# %%
#export all
rel_df[["text", "rel_type"]].to_csv(re_data_path + os.sep + "re_scibert_data.tsv", sep="\t", index=False, header=False)
rel_df["rel_type"].value_counts()
# Out:
# Other    12225
# TeRP       992
# TrAP       884
# PIP        755
# TrCP       184
# TeCP       166
# TrNAP       62
# TrIP        51
# TrWP        24
# Name: rel_type, dtype: int64

# %%
# class test --> problem
test_problem_df = rel_df[(rel_df["concept_type_1"] == "test") & (rel_df["concept_type_2"] == "problem")]
test_problem_df
# Out:
#            filename  line_num  \
# 8      018636330_DH        27
# 9      018636330_DH        27
# 10     018636330_DH        27
# 11     018636330_DH        27
# 12     018636330_DH        27
# ...             ...       ...
# 15211     record-84        70
# 15212     record-84        70
# 15213     record-84        70
# 15214     record-84        70
# 15215     record-84        70
#
#                                                     text     concept_text_1  \
# 8      She had << a workup >> by her neurologist and ...           a workup
# 9      She had << a workup >> by her neurologist and ...           a workup
# 10     She had << a workup >> by her neurologist and ...           a workup
# 11     She had a workup by her neurologist and << an ...             an mri
# 12     She had a workup by her neurologist and << an ...             an mri
# ...                                                  ...                ...
# 15211  The patient had << an echocardiogram >> on day...  an echocardiogram
# 15212  The patient had << an echocardiogram >> on day...  an echocardiogram
# 15213  The patient had << an echocardiogram >> on day...  an echocardiogram
# 15214  The patient had << an echocardiogram >> on day...  an echocardiogram
# 15215  The patient had << an echocardiogram >> on day...  an echocardiogram
#
#                             concept_text_2 rel_type concept_type_1  \
# 8                         cord compression    Other           test
# 9                   a c5-6 disc herniation    Other           test
# 10                      a t2 signal change    Other           test
# 11                        cord compression     TeRP           test
# 12                  a c5-6 disc herniation     TeRP           test
# ...                                    ...      ...            ...
# 15211                   mild symmetric lvh     TeRP           test
# 15212  mild region lv systolic dysfunction     TeRP           test
# 15213     a moderately dilated aortic root     TeRP           test
# 15214     a mildly dilated ascending aorta     TeRP           test
# 15215                pericardial effusions     TeRP           test
#
#       concept_type_2
# 8            problem
# 9            problem
# 10           problem
# 11           problem
# 12           problem
# ...              ...
# 15211        problem
# 15212        problem
# 15213        problem
# 15214        problem
# 15215        problem
#
# [2150 rows x 8 columns]

# %%
# export as tsv
test_problem_df = test_problem_df[["text", "rel_type"]]
test_problem_df.to_csv(re_data_path + os.sep + "re_scibert_data_Te_P.tsv", sep="\t", index=False, header=False)
test_problem_df["rel_type"].value_counts()
# Out:
# Other    992
# TeRP     992
# TeCP     166
# Name: rel_type, dtype: int64

# %%
# class treatment --> problem
treatment_problem_df = rel_df[(rel_df["concept_type_1"] == "treatment") & (rel_df["concept_type_2"] == "problem")]
treatment_problem_df
# Out:
#             filename  line_num  \
# 27      018636330_DH        43
# 29      018636330_DH        47
# 50      018636330_DH        55
# 51     026350193_RWH        45
# 52     026350193_RWH        45
# ...              ...       ...
# 15332      record-84        99
# 15333      record-84        99
# 15334      record-84        99
# 15341      record-84       100
# 15342      record-84       100
#
#                                                     text  \
# 27     She had a postoperative CT scan that revealed ...
# 29     [[ Her pain ]] was under good control with << ...
# 50     3. << Percocet >> , 5/325 , 1-2 tabs PO q4-6h ...
# 51     Take << codeine >> prescribed by PCP with food...
# 52     Take << codeine >> prescribed by PCP with food...
# ...                                                  ...
# 15332  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15333  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15334  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15341  The patient was told he could return to work a...
# 15342  The patient was told he could return to work a...
#
#                      concept_text_1  \
# 27                     her hardware
# 29              po pain medications
# 50                         percocet
# 51                          codeine
# 52                          codeine
# ...                             ...
# 15332           hydrochlorothiazide
# 15333           hydrochlorothiazide
# 15334           hydrochlorothiazide
# 15341  a transdermal nicotine patch
# 15342                          rest
#
#                                   concept_text_2 rel_type concept_type_1  \
# 27     partial decompression of the spinal canal    Other      treatment
# 29                                      her pain     TrIP      treatment
# 50                                          pain     TrAP      treatment
# 51                                  constipation    Other      treatment
# 52                                        nausea    Other      treatment
# ...                                          ...      ...            ...
# 15332                                 chest pain    Other      treatment
# 15333                                   pressure    Other      treatment
# 15334                        shortness of breath    Other      treatment
# 15341                                   cravings     TrAP      treatment
# 15342                                   cravings    Other      treatment
#
#       concept_type_2
# 27           problem
# 29           problem
# 50           problem
# 51           problem
# 52           problem
# ...              ...
# 15332        problem
# 15333        problem
# 15334        problem
# 15341        problem
# 15342        problem
#
# [2909 rows x 8 columns]

# %%
# export as tsv
treatment_problem_df = treatment_problem_df[["text", "rel_type"]]
treatment_problem_df.to_csv(re_data_path + os.sep + "re_scibert_data_Tr_P.tsv", sep="\t", index=False, header=False)
treatment_problem_df["rel_type"].value_counts()
# Out:
# Other    1704
# TrAP      884
# TrCP      184
# TrNAP      62
# TrIP       51
# TrWP       24
# Name: rel_type, dtype: int64

# %%
# class problem --> problem
problem_problem_df = rel_df[(rel_df["concept_type_1"] == "problem") & (rel_df["concept_type_2"] == "problem")]
problem_problem_df
# Out:
#            filename  line_num  \
# 0      018636330_DH        21
# 1      018636330_DH        21
# 2      018636330_DH        21
# 3      018636330_DH        21
# 4      018636330_DH        21
# ...             ...       ...
# 15336     record-84        99
# 15337     record-84        99
# 15338     record-84        99
# 15339     record-84        99
# 15340     record-84        99
#
#                                                     text  \
# 0      << C5-6 disc herniation >> with [[ cord compre...
# 1      << C5-6 disc herniation >> with cord compressi...
# 2      [[ C5-6 disc herniation ]] with << cord compre...
# 3      C5-6 disc herniation with << cord compression ...
# 4      [[ C5-6 disc herniation ]] with cord compressi...
# ...                                                  ...
# 15336  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15337  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15338  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15339  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
# 15340  Aspirin 325 mg q.d. , Plavix 75 mg q.d. , Lipi...
#
#              concept_text_1        concept_text_2 rel_type concept_type_1  \
# 0      c5-6 disc herniation      cord compression      PIP        problem
# 1      c5-6 disc herniation            myelopathy      PIP        problem
# 2          cord compression  c5-6 disc herniation    Other        problem
# 3          cord compression            myelopathy    Other        problem
# 4                myelopathy  c5-6 disc herniation    Other        problem
# ...                     ...                   ...      ...            ...
# 15336            chest pain   shortness of breath    Other        problem
# 15337              pressure            chest pain    Other        problem
# 15338              pressure   shortness of breath    Other        problem
# 15339   shortness of breath            chest pain    Other        problem
# 15340   shortness of breath              pressure    Other        problem
#
#       concept_type_2
# 0            problem
# 1            problem
# 2            problem
# 3            problem
# 4            problem
# ...              ...
# 15336        problem
# 15337        problem
# 15338        problem
# 15339        problem
# 15340        problem
#
# [10284 rows x 8 columns]

# %%
# export as tsv
problem_problem_df = problem_problem_df[["text", "rel_type"]]
problem_problem_df.to_csv(re_data_path + os.sep + "re_scibert_data_P_P.tsv", sep="\t", index=False, header=False)
problem_problem_df["rel_type"].value_counts()
# Out:
# Other    9529
# PIP       755
# Name: rel_type, dtype: int64

# %% [markdown]
# ## Old

# %%
# export as tsv
rel_df.to_csv(re_data_path + os.sep + "re_data_scibert.tsv", sep="\t", index=False, header=False)

# %%
pd.read_csv(re_data_path + os.sep + "re_data_scibert.tsv", nrows=10, sep='\t', header=None)
# Out:
#                                                    0     1
# 0  41 yo man with [[ CRFs ]] of << DM Type II >> ...   PIP
# 1  Here , had T wave flattening laterally and inf...  TeRP
# 2  Here , had << T wave flattening laterally and ...   PIP
# 3  Had << Chest CT >> to r / o dissection ( due t...  TeCP
# 4  Had << Chest CT >> to r / o [[ dissection ]] (...  TeCP
# 5  << Ultrasound >> was performed on 2014-04-01 d...  TeRP
# 6  << Ultrasound >> was performed on 2014-04-01 d...  TeRP
# 7  Ultrasound was performed on 2014-04-01 demonst...   PIP
# 8  Ultrasound was performed on 2014-04-01 demonst...  TrAP
# 9  Ultrasound was performed on 2014-04-01 demonst...  TrAP

# %%
#export as jsonl
rel_df.to_json(re_data_path + os.sep + "re_data.jsonl", orient="records", lines=True)

# %%
# read 10 first lines pandas json
pd.read_json(re_data_path + os.sep + "re_data.jsonl", lines=True, nrows=10)
# Out:
#                                                 text rel_type
# 0  41 yo man with ## CRFs ## of ** DM Type II ** ...      PIP
# 1  Here , had T wave flattening laterally and inf...     TeRP
# 2  Here , had ** T wave flattening laterally and ...      PIP
# 3  Had ** Chest CT ** to r / o dissection ( due t...     TeCP
# 4  Had ** Chest CT ** to r / o ## dissection ## (...     TeCP
# 5  ** Ultrasound ** was performed on 2014-04-01 d...     TeRP
# 6  ** Ultrasound ** was performed on 2014-04-01 d...     TeRP
# 7  Ultrasound was performed on 2014-04-01 demonst...      PIP
# 8  Ultrasound was performed on 2014-04-01 demonst...     TrAP
# 9  Ultrasound was performed on 2014-04-01 demonst...     TrAP

# %%
train_df[1].value_counts()
# Out:
# TeRP     993
# TrAP     884
# PIP      754
# TrCP     184
# TeCP     166
# TrNAP     62
# TrIP      51
# TrWP      24
# Name: 1, dtype: int64
