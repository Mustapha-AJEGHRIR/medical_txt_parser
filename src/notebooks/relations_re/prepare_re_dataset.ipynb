# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mustapha-AJEGHRIR/medical_txt_parser/blob/main/src/notebooks/assertions_nli/ast_nli_scibert.ipynb)

# %% [markdown]
# # Prepare RE dataset
# scibert: https://raw.githubusercontent.com/allenai/scibert/master/data/text_classification/chemprot/train.txt
#
# scifive: https://github.com/justinphan3110/SciFive

# %%
# %%capture
# !pip install seqeval transformers datasets spacy sentence_transformers

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/projects/medical_txt_parser

# %%
# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

path = %pwd
while "src" in path:
    # %cd ..
    path = %pwd

import glob
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
from pprint import pprint
import matplotlib.pyplot as plt
import re

import transformers
from datasets import Dataset, ClassLabel, Sequence, load_dataset, load_metric
from spacy import displacy

assert transformers.__version__ >= "4.11.0"

from src.utils.parse_data import parse_ast, parse_concept, parse_relation

# %%
train_data_path = "data/train"
val_data_path = "data/val"
ast_folder_name = "ast"
concept_folder_name = "concept"
rel_folder_name = "rel"
txt_folder_name = "txt"
re_data_path = "data/re"
os.makedirs(re_data_path, exist_ok=True)

# %% [markdown]
# ### Import data

# %%
text_files = glob.glob(train_data_path + os.sep + txt_folder_name + os.sep +  "*.txt")
filename = ""
df = pd.DataFrame()
for file in tqdm(text_files):
    with open(file, 'r') as f:
        text = f.read()
        filename = file.split("/")[-1].split(".")[0]
        concept = parse_concept(train_data_path + os.sep + concept_folder_name + os.sep +  filename + ".con")
        rel = parse_relation(train_data_path + os.sep + rel_folder_name + os.sep +  filename + ".rel")
        
        df = df.append(pd.DataFrame({"text": [text], "filename": [filename] , "concept": [concept], "rel":[rel]}), ignore_index=True)
df.head()
# Out:
# 100%|██████████| 170/170 [00:00<00:00, 392.26it/s]
#                                                 text      filename  \
# 0  143748600 SC\n43243309\n095342\n09/30/2000 12:...  143748600_SC
# 1  Admission Date :\n2014-03-31\nDischarge Date :...     record-56
# 2  699905656 SC\n06100044\n921737\n1/17/1993 12:0...  699905656_SC
# 3  627258104\nGH\n56900479\n1/8/2001 12:00:00 AM\...     627258104
# 4  839999049 YC\n59242403\n431924\n11/01/2000 12:...  839999049_YC
#
#                                              concept  \
# 0  {'concept_text': ['htn', 'atypical chest pain'...
# 1  {'concept_text': ['the procedure', 'auscultati...
# 2  {'concept_text': ['right sided sciatica proced...
# 3  {'concept_text': ['bradycardia', 'subsequent f...
# 4  {'concept_text': ['pauses', 'outpt fitting', '...
#
#                                                  rel
# 0  {'concept_text_1': ['dm type ii', 'lead placem...
# 1  {'concept_text_1': ['ultrasound', 'ultrasound'...
# 2  {'concept_text_1': ['ct myelogram', 'ct myelog...
# 3  {'concept_text_1': ['bradycardia', 'a chest xr...
# 4  {'concept_text_1': ['ett', 'desaturations in t...

# %%
concept_df = pd.DataFrame(columns=[ "filename"]+list(concept.keys()))
for i, file in df.iterrows():
    concept_dict = file["concept"]
    tmp = pd.DataFrame(concept_dict)
    tmp["filename"] = file["filename"]
    concept_df = concept_df.append(tmp, ignore_index=True)
concept_df
# Out:
#            filename                   concept_text start_line  \
# 0      143748600_SC                            htn         52
# 1      143748600_SC            atypical chest pain          5
# 2      143748600_SC   wellbutrin ( bupropion hcl )         33
# 3      143748600_SC                            ett         58
# 4      143748600_SC                     dissection         56
# ...             ...                            ...        ...
# 16520     105732749  repeated fleet &apos;s enemas         53
# 16521     105732749                         biopsy         23
# 16522     105732749                   respirations         39
# 16523     105732749                    these tests         61
# 16524     105732749             abdominal cramping         52
#
#       start_word_number end_line end_word_number concept_type
# 0                    19       52              19      problem
# 1                     0        5               2      problem
# 2                    19       33              23    treatment
# 3                     3       58               3         test
# 4                     7       56               7      problem
# ...                 ...      ...             ...          ...
# 16520                 4       53               7    treatment
# 16521                 2       23               2         test
# 16522                 9       39               9         test
# 16523                11       61              12         test
# 16524                11       52              12      problem
#
# [16525 rows x 7 columns]

# %%
rel_df = pd.DataFrame(columns=[ "filename"]+list(rel.keys()))
for i, file in df.iterrows():
    rel_dict = file["rel"]
    tmp = pd.DataFrame(rel_dict)
    tmp["filename"] = file["filename"]
    rel_df = rel_df.append(tmp, ignore_index=True)
rel_df
# Out:
#           filename                              concept_text_1 start_line_1  \
# 0     143748600_SC                                  dm type ii           52
# 1     143748600_SC                              lead placement           55
# 2     143748600_SC  t wave flattening laterally and inferiorly           55
# 3     143748600_SC                                    chest ct           56
# 4     143748600_SC                                    chest ct           56
# ...            ...                                         ...          ...
# 3115     105732749                                   a ct scan           27
# 3116     105732749                                    percocet           58
# 3117     105732749                                   specimens           48
# 3118     105732749                               the procedure           49
# 3119     105732749                                      repair           30
#
#      start_word_number_1 end_line_1 end_word_number_1        concept_text_2  \
# 0                      6         52                 8                  crfs
# 1                     20         55                21                  pain
# 2                      3         55                 8                  pain
# 3                      1         56                 2             back pain
# 4                      1         56                 2            dissection
# ...                  ...        ...               ...                   ...
# 3115                  18         27                20                a mass
# 3116                   0         58                 0                  pain
# 3117                   0         48                 0     falciform nodules
# 3118                   9         49                10         complications
# 3119                  11         30                11  a ureteral stricture
#
#      start_line_2 start_word_number_2 end_line_2 end_word_number_2  \
# 0              52                   4         52                 4
# 1              55                  10         55                10
# 2              55                  10         55                10
# 3              56                  11         56                12
# 4              56                   7         56                 7
# ...           ...                 ...        ...               ...
# 3115           27                  24         27                25
# 3116           58                  12         58                12
# 3117           48                  14         48                15
# 3118           49                   3         49                 3
# 3119           30                  13         30                15
#
#      relation_type
# 0              PIP
# 1             TeRP
# 2              PIP
# 3             TeCP
# 4             TeCP
# ...            ...
# 3115          TeRP
# 3116          TrAP
# 3117          TeCP
# 3118          TrCP
# 3119          TrAP
#
# [3120 rows x 12 columns]

# %%
# extract relations from column "relation_type"
label_dict = {"Tr":"treatment", "Te":"test", "PIP":"problem"}
rel_df["rel_type1"] = rel_df["relation_type"].apply(lambda x: re.findall(r'[A-Z](?:[a-z]+|[A-Z]*(?=[A-Z]|$))', x)[0]).apply(lambda x: label_dict[x])
rel_df["rel_type2"] = "problem"

# extract realtions from concept files
merge_df = pd.merge(concept_df, rel_df, left_on=["filename","start_line","start_word_number","end_line","end_word_number"], right_on=["filename","start_line_1","start_word_number_1","end_line_1","end_word_number_1"], how="inner")
assert len(merge_df[merge_df["concept_text"] != merge_df["concept_text_1"]]) == 0, "concept_text is not equal to concept_text_1"
rel_df["concept_type_1"] = merge_df["concept_type"]

merge_df = pd.merge(concept_df, rel_df, left_on=["filename","start_line","start_word_number","end_line","end_word_number"], right_on=["filename","start_line_2","start_word_number_2","end_line_2","end_word_number_2"], how="inner")
assert len(merge_df[merge_df["concept_text"] != merge_df["concept_text_2"]]) == 0, "concept_text is not equal to concept_text_2"
rel_df["concept_type_2"] = merge_df["concept_type"]

rel_df
# Out:
#           filename                              concept_text_1 start_line_1  \
# 0     143748600_SC                                  dm type ii           52
# 1     143748600_SC                              lead placement           55
# 2     143748600_SC  t wave flattening laterally and inferiorly           55
# 3     143748600_SC                                    chest ct           56
# 4     143748600_SC                                    chest ct           56
# ...            ...                                         ...          ...
# 3115     105732749                                   a ct scan           27
# 3116     105732749                                    percocet           58
# 3117     105732749                                   specimens           48
# 3118     105732749                               the procedure           49
# 3119     105732749                                      repair           30
#
#      start_word_number_1 end_line_1 end_word_number_1        concept_text_2  \
# 0                      6         52                 8                  crfs
# 1                     20         55                21                  pain
# 2                      3         55                 8                  pain
# 3                      1         56                 2             back pain
# 4                      1         56                 2            dissection
# ...                  ...        ...               ...                   ...
# 3115                  18         27                20                a mass
# 3116                   0         58                 0                  pain
# 3117                   0         48                 0     falciform nodules
# 3118                   9         49                10         complications
# 3119                  11         30                11  a ureteral stricture
#
#      start_line_2 start_word_number_2 end_line_2 end_word_number_2  \
# 0              52                   4         52                 4
# 1              55                  10         55                10
# 2              55                  10         55                10
# 3              56                  11         56                12
# 4              56                   7         56                 7
# ...           ...                 ...        ...               ...
# 3115           27                  24         27                25
# 3116           58                  12         58                12
# 3117           48                  14         48                15
# 3118           49                   3         49                 3
# 3119           30                  13         30                15
#
#      relation_type  rel_type1 rel_type2 concept_type_1 concept_type_2
# 0              PIP    problem   problem        problem        problem
# 1             TeRP       test   problem           test        problem
# 2              PIP    problem   problem        problem        problem
# 3             TeCP       test   problem           test        problem
# 4             TeCP       test   problem           test        problem
# ...            ...        ...       ...            ...            ...
# 3115          TeRP       test   problem           test        problem
# 3116          TrAP  treatment   problem      treatment        problem
# 3117          TeCP       test   problem           test        problem
# 3118          TrCP  treatment   problem      treatment        problem
# 3119          TrAP  treatment   problem      treatment        problem
#
# [3120 rows x 16 columns]

# %% [markdown]
# Dissimilarities between concept files and relation files

# %%
rel_df[rel_df["concept_type_1"] != rel_df["rel_type1"]]
# Out:
# Empty DataFrame
# Columns: [filename, concept_text_1, start_line_1, start_word_number_1, end_line_1, end_word_number_1, concept_text_2, start_line_2, start_word_number_2, end_line_2, end_word_number_2, relation_type, rel_type1, rel_type2, concept_type_1, concept_type_2]
# Index: []

# %%
rel_df[rel_df["concept_type_2"] != rel_df["rel_type2"]]
# Out:
#         filename concept_text_1 start_line_1 start_word_number_1 end_line_1  \
# 1392  record-177   levofloxacin          122                  18        122
# 1874   record-18         anemia          104                  17        104
#
#      end_word_number_1 concept_text_2 start_line_2 start_word_number_2  \
# 1392                18            uti          122                   9
# 1874                17       high mcv          104                   6
#
#      end_line_2 end_word_number_2 relation_type  rel_type1 rel_type2  \
# 1392        122                 9          TrAP  treatment   problem
# 1874        104                 7           PIP    problem   problem
#
#      concept_type_1 concept_type_2
# 1392      treatment           test
# 1874        problem      treatment

# %%
# check same start line
rel_df[rel_df["start_line_2"] != rel_df["start_line_1"]]
# Out:
# Empty DataFrame
# Columns: [filename, concept_text_1, start_line_1, start_word_number_1, end_line_1, end_word_number_1, concept_text_2, start_line_2, start_word_number_2, end_line_2, end_word_number_2, relation_type, rel_type1, rel_type2, concept_type_1, concept_type_2]
# Index: []

# %%
# we drop dissimilarities
rel_df.drop(rel_df[rel_df["concept_type_1"] != rel_df["rel_type1"]].index, inplace=True)
rel_df.drop(rel_df[rel_df["concept_type_2"] != rel_df["rel_type2"]].index, inplace=True)


def preprocess_text(row):
    text = row["text"]
    # find line
    # text = text.lower()
    line = text.split("\n")[row["start_line_1"]-1]
    line = " ".join(line.split()) # remove multiple spaces

    concept_text_1 = "<< "+ " ".join(line.split()[row["start_word_number_1"]:row["end_word_number_1"]+1]) + " >>"
    concept_text_2 = "[[ " + " ".join(line.split()[row["start_word_number_2"]:row["end_word_number_2"]+1]) + " ]]"
    start_word_number_1 = row["start_word_number_1"]
    end_word_number_1 = row["end_word_number_1"]
    start_word_number_2 = row["start_word_number_2"]
    end_word_number_2 = row["end_word_number_2"]

    if row["start_word_number_1"] > row["start_word_number_2"]:
        concept_text_1, concept_text_2 = concept_text_2, concept_text_1
        start_word_number_1, start_word_number_2 = start_word_number_2, start_word_number_1
        end_word_number_1, end_word_number_2 = end_word_number_2, end_word_number_1
    text = " ".join(line.split()[: start_word_number_1] + [concept_text_1] + line.split()[end_word_number_1+1: start_word_number_2] + [concept_text_2] + line.split()[end_word_number_2+1:])

    row["text"] = text
    return row

rel_df = rel_df.merge(df[["filename","text"]], on="filename", how="inner")
rel_df = rel_df.apply(preprocess_text, axis=1)
rel_df = rel_df[["filename","start_line_1", "text", "concept_text_1", "concept_text_2", "relation_type", "concept_type_1", "concept_type_2"]]
rel_df.columns = ["filename","line_num", "text", "concept_text_1", "concept_text_2", "rel_type", "concept_type_1", "concept_type_2"]
rel_df
# Out:
#           filename  line_num  \
# 0     143748600_SC        52
# 1     143748600_SC        55
# 2     143748600_SC        55
# 3     143748600_SC        56
# 4     143748600_SC        56
# ...            ...       ...
# 3113     105732749        27
# 3114     105732749        58
# 3115     105732749        48
# 3116     105732749        49
# 3117     105732749        30
#
#                                                    text  \
# 0     41 yo man with [[ CRFs ]] of << DM Type II >> ...
# 1     Here , had T wave flattening laterally and inf...
# 2     Here , had << T wave flattening laterally and ...
# 3     Had << Chest CT >> to r / o dissection ( due t...
# 4     Had << Chest CT >> to r / o [[ dissection ]] (...
# ...                                                 ...
# 3113  She presented to her primary care physician , ...
# 3114  << Percocet >> one to two whenever necessary q...
# 3115  << Specimens >> sent to pathology included per...
# 3116  There were no [[ complications ]] , and the pa...
# 3117  Is significant for spinal stenosis and a serie...
#
#                                   concept_text_1        concept_text_2  \
# 0                                     dm type ii                  crfs
# 1                                 lead placement                  pain
# 2     t wave flattening laterally and inferiorly                  pain
# 3                                       chest ct             back pain
# 4                                       chest ct            dissection
# ...                                          ...                   ...
# 3113                                   a ct scan                a mass
# 3114                                    percocet                  pain
# 3115                                   specimens     falciform nodules
# 3116                               the procedure         complications
# 3117                                      repair  a ureteral stricture
#
#      rel_type concept_type_1 concept_type_2
# 0         PIP        problem        problem
# 1        TeRP           test        problem
# 2         PIP        problem        problem
# 3        TeCP           test        problem
# 4        TeCP           test        problem
# ...       ...            ...            ...
# 3113     TeRP           test        problem
# 3114     TrAP      treatment        problem
# 3115     TeCP           test        problem
# 3116     TrCP      treatment        problem
# 3117     TrAP      treatment        problem
#
# [3118 rows x 8 columns]

# %%
rel_df = rel_df[["text", "rel_type"]]
rel_df
# Out:
#                                                    text rel_type
# 0     41 yo man with [[ CRFs ]] of << DM Type II >> ...      PIP
# 1     Here , had T wave flattening laterally and inf...     TeRP
# 2     Here , had << T wave flattening laterally and ...      PIP
# 3     Had << Chest CT >> to r / o dissection ( due t...     TeCP
# 4     Had << Chest CT >> to r / o [[ dissection ]] (...     TeCP
# ...                                                 ...      ...
# 3113  She presented to her primary care physician , ...     TeRP
# 3114  << Percocet >> one to two whenever necessary q...     TrAP
# 3115  << Specimens >> sent to pathology included per...     TeCP
# 3116  There were no [[ complications ]] , and the pa...     TrCP
# 3117  Is significant for spinal stenosis and a serie...     TrAP
#
# [3118 rows x 2 columns]

# %%
# export as tsv
rel_df.to_csv(re_data_path + os.sep + "re_data_scibert.tsv", sep="\t", index=False, header=False)

# %%
pd.read_csv(re_data_path + os.sep + "re_data_scibert.tsv", nrows=10, sep='\t', header=None)
# Out:
#                                                    0     1
# 0  41 yo man with [[ CRFs ]] of << DM Type II >> ...   PIP
# 1  Here , had T wave flattening laterally and inf...  TeRP
# 2  Here , had << T wave flattening laterally and ...   PIP
# 3  Had << Chest CT >> to r / o dissection ( due t...  TeCP
# 4  Had << Chest CT >> to r / o [[ dissection ]] (...  TeCP
# 5  << Ultrasound >> was performed on 2014-04-01 d...  TeRP
# 6  << Ultrasound >> was performed on 2014-04-01 d...  TeRP
# 7  Ultrasound was performed on 2014-04-01 demonst...   PIP
# 8  Ultrasound was performed on 2014-04-01 demonst...  TrAP
# 9  Ultrasound was performed on 2014-04-01 demonst...  TrAP

# %%
#export as jsonl
rel_df.to_json(re_data_path + os.sep + "re_data.jsonl", orient="records", lines=True)

# %%
# read 10 first lines pandas json
pd.read_json(re_data_path + os.sep + "re_data.jsonl", lines=True, nrows=10)
# Out:
#                                                 text rel_type
# 0  41 yo man with ## CRFs ## of ** DM Type II ** ...      PIP
# 1  Here , had T wave flattening laterally and inf...     TeRP
# 2  Here , had ** T wave flattening laterally and ...      PIP
# 3  Had ** Chest CT ** to r / o dissection ( due t...     TeCP
# 4  Had ** Chest CT ** to r / o ## dissection ## (...     TeCP
# 5  ** Ultrasound ** was performed on 2014-04-01 d...     TeRP
# 6  ** Ultrasound ** was performed on 2014-04-01 d...     TeRP
# 7  Ultrasound was performed on 2014-04-01 demonst...      PIP
# 8  Ultrasound was performed on 2014-04-01 demonst...     TrAP
# 9  Ultrasound was performed on 2014-04-01 demonst...     TrAP

# %%
train_df[1].value_counts()
# Out:
# TeRP     993
# TrAP     884
# PIP      754
# TrCP     184
# TeCP     166
# TrNAP     62
# TrIP      51
# TrWP      24
# Name: 1, dtype: int64
