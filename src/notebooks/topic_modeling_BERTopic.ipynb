# %% [markdown]
# ## Topic Models
# Dynamic topic models can be used to vizualise the topics of a collection of documents.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">
#
# Inspired by this notebook: https://colab.research.google.com/drive/1FieRA9fLdkQEGDIMYl0I3MCjSUKVF8C-?usp=sharing

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**

# %%
# %cd ../..
# Out:
# /content/drive/MyDrive/projects/medical_txt_parser

# %%
import glob
import pandas as pd
import os
from pprint import pprint

import matplotlib.pyplot as plt

from src.utils.parse_data import parse_ast, parse_concept, parse_relation

# %%
train_data_path = "data/train"
val_data_path = "data/val"
ast_folder_name = "ast"
concept_folder_name = "concept"
rel_folder_name = "rel"
txt_folder_name = "txt"

# %%
text_files = glob.glob(train_data_path + os.sep + txt_folder_name + os.sep +  "*.txt")
filename = ""
df = pd.DataFrame()
from tqdm import tqdm
for file in tqdm(text_files):
    with open(file, 'r') as f:
        text = f.read()
        filename = file.split("/")[-1].split(".")[0]
        concept = parse_concept(train_data_path + os.sep + concept_folder_name + os.sep +  filename + ".con")
        
        df = df.append(pd.DataFrame({"text": [text], "filename": [filename] , "concept": [concept]}), ignore_index=True)
df.head()
# Out:
# 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
#                                                 text  ...                                            concept
# 0  Admission Date :\n2017-08-14\nDischarge Date :...  ...  {'concept_text': ['cyanotic', 'a more pervasiv...
# 1  Admission Date :\n2014-10-21\nDischarge Date :...  ...  {'concept_text': ['intraparenchymal bleed', 'i...
# 2  Admission Date :\n2017-06-13\nDischarge Date :...  ...  {'concept_text': ['left basilar atelectasis', ...
# 3  Admission Date :\n2015-10-05\nDischarge Date :...  ...  {'concept_text': ['vomiting', 'asa', 'ck-mb', ...
# 4  Admission Date :\n2015-06-05\nDischarge Date :...  ...  {'concept_text': ['his respiratory distress', ...
#
# [5 rows x 3 columns]

# %%
concept_df = pd.DataFrame(columns=[ "filename"]+list(concept.keys()))
for i, file in df.iterrows():
    concept_dict = file["concept"]
    tmp = pd.DataFrame(concept_dict)
    tmp["filename"] = file["filename"]
    concept_df = concept_df.append(tmp, ignore_index=True)
concept_df.head()
# Out:
#      filename                     concept_text  ... end_word_number concept_type
# 0  record-142                         cyanotic  ...               5      problem
# 1  record-142         a more pervasive process  ...              27      problem
# 2  record-142                     old twi v4-6  ...               2      problem
# 3  record-142  his new , severe global deficit  ...              15      problem
# 4  record-142            anoxic encephalopathy  ...              31      problem
#
# [5 rows x 7 columns]

# %%
texts = concept_df.concept_text.values.tolist()
texts
# Out:
# ['cyanotic',
#  'a more pervasive process',
#  'old twi v4-6',
#  'his new , severe global deficit',
#  'anoxic encephalopathy',
#  'rate',
#  'ekg',
#  'anemia of chronic disease',
#  'sepsis',
#  'the left ventricular inflow pattern',
#  'impaired relaxation',
#  'vancomycin',
#  'mrsa',
#  'pseudomonas',
#  'mild ( 1+ ) aortic regurgitation',
#  'jevity',
#  'dusky',
#  'long qt interval',
#  'st depressions v4 , 5',
#  'hr',
#  'the ventilator',
#  'pseudomonas aeruginosa',
#  'bp',
#  'qtc',
#  'lansoprazole',
#  'ac',
#  'aortic valve stenosis',
#  'hyponatremia',
#  'asa',
#  'mild st elevation in v3',
#  'cxr',
#  'vancomycin',
#  'vt',
#  'abg',
#  'subsequent tracheostomy',
#  'respiratory failure',
#  'pulmonary edema',
#  'lasix',
#  'peep',
#  'fio2',
#  'old twi v4-6',
#  'metoprolol',
#  'failure to wean',
#  'mildly dilated',
#  'rr',
#  's/p right pneumonectomy',
#  'ac',
#  'fio2',
#  'zosyn',
#  'hr',
#  'effusion',
#  'heparin',
#  'blunting of left cpa',
#  'bp',
#  'fio2',
#  'albuterol inhaler',
#  'non-small cell lung cancer',
#  'flagyl',
#  'fi02',
#  'new lower left lateral cw opacity',
#  'loculated pleural fluid',
#  's/p xrt',
#  'ipratropium',
#  'right pneumonectomy',
#  'a small pericardial effusion',
#  'occasional v-paced',
#  'resting wma',
#  'vt',
#  'pseudomonal pneumonia',
#  'echo',
#  'anoxic encephalopathy',
#  'medicine',
#  'peep',
#  'volume overload',
#  'left-to-right shunt across the interatrial septum',
#  'sbp',
#  'chronic respiratory failure',
#  'a morphine drip',
#  'lvef',
#  'rr',
#  's/p right pneumonectomy',
#  'recurrence',
#  'non-small cell lung cancer',
#  'mid to distal septal akinesis',
#  'apical akinesis',
#  'trivial mitral regurgitation',
#  'ekg',
#  'acute changes',
#  'chemotherapy',
#  'inferior akinesis/hypokinesis',
#  'mid to distal anterolateral hypokinesis',
#  'bp',
#  'this head ct',
#  'hypertension',
#  'chronic left pleural effusion',
#  'chemotherapy',
#  'akinesis',
#  'recurrence',
#  'sick sinus syndrome',
#  's/p right pneumonectomy',
#  'apical thrombus',
#  's4',
#  'ar',
#  'lymphs',
#  'neuts',
#  'rdw',
#  'ronchorous breath sounds left chest',
#  'peg',
#  'urea n',
#  'basos',
#  'tamponade',
#  'tr',
#  'eos',
#  'trivial mr',
#  'chronic obstructive pulmonary disease',
#  'ct head',
#  'epileptiform features',
#  'murmur',
#  'painful stimulus',
#  'monos',
#  'subacute infarction',
#  'head ct',
#  'creat',
#  'hr',
#  'new rounded low-density area',
#  'subcortical dysfunction on the right side',
#  'glucose',
#  'fluid overload',
#  'the evaluation',
#  'plt count',
#  'status post tracheostomy',
#  'failure',
#  'comfort measures only',
#  'limited examination',
#  'so-called pseudotumor',
#  'mri',
#  'chloride',
#  'echocardiographic signs',
#  'potassium',
#  'echo',
#  'all medications',
#  'bp',
#  'the recent chest x-ray',
#  'small loculated pleural fluid collection along the periphery',
#  'painful stimulus',
#  'sodium',
#  'lactate',
#  'overall lvef',
#  'k+',
#  'c.difficile colitis',
#  'total co2',
#  'the basal lv',
#  'hyperdynamic',
#  'regional contraction abnormality',
#  'ac',
#  'anion gap',
#  'vancomycin',
#  'pco2',
#  'flagyl',
#  'eeg',
#  'ph',
#  'ventilator dependent',
#  'markedly abnormal portable eeg',
#  'the bursts of generalized slowing',
#  'the voltage suppression over the left hemisphere',
#  'right hemisphere slowing',
#  'art po2',
#  'zosyn',
#  'the first abnormality',
#  'widespread cortical dysfunction on that side',
#  'material ( such as subdural fluid ) interposed between the brain',
#  'base xs',
#  'intubated',
#  'total co2',
#  'the generalized slowing',
#  'a non specific dysfunction in midline structures',
#  's/p xrt',
#  'jvp',
#  'a pseudomonal pneumonia',
#  'sputum cultures',
#  'bronchiectasis',
#  'atrial fibrillation',
#  'his recent acute decline in mental status',
#  'intubated',
#  'this work-up',
#  'a small left basal ganglia infarct',
#  'cardioembolic',
#  'ekg',
#  'intubated',
#  'status post partial colectomy',
#  'status post peg tube placement',
#  'c.diff',
#  'cta chest',
#  'vancomycin',
#  'sepsis',
#  'recent mrsa pneumonia',
#  'stool clostridium difficile toxin assay',
#  'masses',
#  'flagyl',
#  'copd/bronchiectasis',
#  'stopped breathing',
#  'bronchial breathing over right hemithorax',
#  'status post pm/icd placement',
#  'drainage',
#  'painful stimulus',
#  'prior study',
#  'sclera anicteric',
#  'pupils minimally reactive',
#  'left femoral av fistula',
#  'sacral edema',
#  'depression',
#  'cool extremities',
#  'failure to wean',
#  'fungal culture',
#  'copd/bronchiectasis',
#  'limited examination',
#  'thrombi',
#  'bph',
#  'last echo',
#  'foley',
#  '2+ edema both upper extremities',
#  'protein / soy supplement',
#  'hct',
#  'mcv',
#  'c. difficile colitis',
#  'mch',
#  'flagyl',
#  'mchc',
#  'wbc',
#  'rbc',
#  'fluid culture',
#  'hgb',
#  'respiratory failure',
#  'mucus plugging',
#  'rate',
#  'cad',
#  'occasional v-paced',
#  'bph',
#  'left femoral av fistula',
#  'pulmonary embolism',
#  'acute respiratory failure',
#  'hypertension',
#  'echo windows',
#  'depression',
#  'afib',
#  'chf',
#  'bp',
#  'cad',
#  'eeg',
#  'spinal fluid gram stain',
#  'chf',
#  'stemi',
#  'last echo',
#  'ivf',
#  'ef',
#  'blood culture',
#  'sulfonamides',
#  'levophed',
#  'vancomycin',
#  'sepsis',
#  'recent mrsa pneumonia',
#  'ef',
#  'chronic left pleural effusion',
#  'abg',
#  'lumbar puncture',
#  'ett',
#  'sss',
#  'pm wires',
#  'sputum culture',
#  'status post pm/icd placement',
#  'viral culture',
#  'coughing',
#  'palpation',
#  'grimacing',
#  'urine culture',
#  'vancomycin',
#  'acid fast culture',
#  'hypoactive',
#  'chronic respiratory distress',
#  'ps',
#  'lp',
#  'blood culture',
#  'continued weaning',
#  'further management',
#  'status post tracheostomy',
#  'failure to wean',
#  'stool',
#  'status post partial colectomy',
#  'bp dropped',
#  'vitals',
#  'ns ivf',
#  'c. difficile colitis',
#  'status post peg tube placement',
#  'pulse',
#  'flagyl',
#  'echo windows',
#  'intraparenchymal bleed',
#  'inr(pt)',
#  'dobhoff',
#  'intraparenchymal hemorrhage',
#  'pt',
#  'his bensodiazapines',
#  'ptt',
#  'extensive carotid arterial calcifications',
#  'decreasing ventillary support.',
#  'complication',
#  'prevertebral soft tissue swelling',
#  'right sided weakness',
#  'tracheostomy',
#  'plt count',
#  'minimally displaced , comminuted fractures of the left c7 and t1 transverse processes',
#  'zosyn',
#  'aspiration',
#  'mrsa pneumonia',
#  'rdw',
#  'atlantoaxial subluxation',
#  'decreased pulmonary secretions',
#  'ct c - spine w/o contrast',
#  'total co2',
#  'bnzodzpn',
#  'fevers',
#  'po2',
#  'ethanol',
#  'linazolid',
#  'levo',
#  'asa',
#  'ct c - spine w/o contrast',
#  'pco2',
#  'amphetmn',
#  'mthdone',
#  'edema',
#  'vanc',
#  'temp',
#  'ph',
#  'congestion',
#  'cocaine',
#  'opiates',
#  'bisacodyl',
#  'constipation',
#  'barbitrt',
#  'bnzodzpn',
#  'docusate sodium',
#  'metoprolol tartrate',
#  'urine',
#  'tricyclic',
#  'digoxin',
#  'lansoprazole',
#  'barbitrt',
#  'linezolid',
#  'colostomy',
#  'ulcerative colitis',
#  'lisinopril',
#  'pacemaker',
#  'ovoid 18 - mm density within the atrium',
#  'decreased blood',
#  'the study',
#  'noncontrast cervical spine ct',
#  'cva',
#  'heparin ( porcine )',
#  'serial ct head',
#  'this study',
#  'assessment of alignment',
#  'g/j tube',
#  'bronchoscopy',
#  'physical / occupational therapy',
#  'diffuse brain atrophy',
#  'an outside study',
#  'supporting tubes and lines',
#  'non-contrast head ct',
#  'prior studies',
#  'hemorrhage',
#  'an ng tube',
#  'a single lead pacemaker',
#  'left rib fractures',
#  'a small amount of blood layering in both lateral ventricles',
#  'bleed',
#  'bleed',
#  'c7 & t1 mimimally displaced transverse process fracture',
#  'chronic microvascular infarction',
#  'decreased attenuation in the periventricular and subcortical white matter',
#  'multiple left-sided rib fractures',
#  'ct head w/o contrast',
#  'surrounding edema',
#  'bilateral intraventricular hemorrhage',
#  'an 18 x 10 mm nodular area of increased density',
#  'intubated',
#  'desats',
#  'non-contrast head ct',
#  'a small amount of hemorrhage',
#  'left t1 transverse process fracture',
#  'shift of normally midline structures',
#  'consitpation',
#  'this study',
#  'subarachnoid hemorrhage',
#  'acute major vascular territorial infarction',
#  'the outside examination',
#  'chronic microvascular infarction throughout the white matter',
#  'magnesium hydroxide',
#  'peep',
#  'tracheostomy',
#  'nasogastric tube placement',
#  'extreme head tilting to the right',
#  'intubation',
#  'iodine containing',
#  'o2',
#  'intubation',
#  'some interstitial edema',
#  'noncontrast cervical spine ct',
#  'minimally displaced and comminuted fractures through the left c7 and t1 transverse processes',
#  'failed swallow study',
#  'sedated',
#  'iodine',
#  'this study',
#  'extension into the foramina transversaria',
#  'multiple spinal fractures',
#  'ct head w/o contrast',
#  'opacification of the visualized left mastoid air cells and mastoid tip',
#  'sclerosis',
#  'studies',
#  'disease',
#  'mild bronchiectasis',
#  'the right upper lobe pneumonia',
#  'supporting lines and tubes',
#  'subarachnoid hemorrhage',
#  'biapical lung scarring',
#  'an intraventricular mass',
#  'atrial fibrillation',
#  'an atypically located blood clot',
#  'pneumonia',
#  'right upper lobe consolidation',
#  'intraventricular hemorrhage',
#  'mchc',
#  'ct head w/o contrast',
#  'mch',
#  'ct head w/o contrast',
#  'contrast - enhanced mri of the brain',
#  'trauma',
#  'hct',
#  'subarachnoid hemorrhage',
#  'hgb',
#  'a remote right frontal infarct',
#  'mcv',
#  'your cervical collar',
#  'opacified and sclerotic left mastoid air cells',
#  'rates',
#  'opacification of the posterior nasal cavity and nasopharynx',
#  'rbc',
#  'skull fracture',
#  'aado2',
#  'the previous study',
#  'an old right frontal lobe cortical infarction',
#  'acetmnphn',
#  'tidal vol',
#  'a small right occipital lobe chronic infarction',
#  'some fluid',
#  'hypertension',
#  'new hemorrhage',
#  'base xs',
#  'opacification of the mastoid air cells',
#  'req o2',
#  'altered mental status',
#  'coronary artery disease',
#  'coumadin',
#  'altered mental status',
#  'a previous study',
#  'an early bilateral upper extermity contracture at the elbows and wrists',
#  'altered mental status',
#  'cataracts',
#  'cataract surgery',
#  'axial noncontrast ct scans of the brain',
#  'chest ( portable ap )',
#  'ativan',
#  'agitation',
#  'chest ( portable ap )',
#  'haldol',
#  'fever',
#  'pmv placement',
#  'fever',
#  'infiltrte',
#  'creat',
#  'previous cxr',
#  'sodium',
#  'hemorrhage',
#  'potassium',
#  'decreased intraventricular blood',
#  'new cortical territorial infarction',
#  'turp',
#  'the previous study',
#  'soft c-collar',
#  'glucose',
#  'hydrocephalus',
#  'sah',
#  'ct head',
#  'edema',
#  'significant radiographic change',
#  'phosphate',
#  'central pulmonary vascular congestion',
#  'urea n',
#  'rib fx',
#  'cardiac size',
#  'trauma',
#  'fluid layering at the apices and the pleural spaces',
#  'wbc',
#  'mucosal thickening in the ethmoid and sphenoid sinuses',
#  'calcification',
#  'magnesium',
#  'fever',
#  'infiltrte',
#  'chloride',
#  'anion gap',
#  'total co2',
#  'fever',
#  'congestive heart failure',
#  'calcium',
#  'pneumonia',
#  'portable supine chest radiograph',
#  'left basilar atelectasis',
#  'ventral hernia',
#  'htn',
#  'spontaneous echo contrast',
#  'cath',
#  '80% lm lesion',
#  'interstitial edema',
#  'ef',
#  'abnormal ekg',
#  'coronary bypass surgery',
#  'right facial plating',
#  'htn',
#  'recent mild angina',
#  'mg',
#  'ef',
#  'perfusion defects',
#  'cabg',
#  'two view chest',
#  'ai',
#  'a right internal jugular vascular catheter',
#  'pefusion imaging',
#  'urean',
#  'rosuvastatin',
#  'svg to om',
#  'creat',
#  'furosemide',
#  'cad',
#  'known allergies',
#  'ventral hernia repair',
#  'ptt',
#  'blood',
#  'right nephrectomy',
#  'drugs',
#  'pt',
#  'docusate sodium',
#  'abnormal stress test',
#  'a swan-ganz catheter',
#  'blood',
#  'mildly thickened',
#  'trace aortic regurgitation',
#  'blood',
#  'blood',
#  'mild symmetric left ventricular hypertrophy',
#  'hgb',
#  'mildly thickened',
#  'mass',
#  'rdw',
#  'plt ct',
#  'pericardial effusion',
#  'right basilar atelectasis',
#  'aortic valve stenosis',
#  'svg to ramus',
#  'trivial mitral regurgitation',
#  'phenylephrine',
#  'lima to lad',
#  'k',
#  'blood',
#  'trace mr',
#  'wbc',
#  'lvef',
#  'right facial droop',
#  'cabg',
#  'plt ct',
#  'pt',
#  'metal plate',
#  'gsw',
#  'inr',
#  'hct',
#  'ventral hernia',
#  'crestor',
#  'simple atheroma',
#  'emergency cabg',
#  'scheduled cath',
#  'temp',
#  'simple atheroma',
#  'afebrile',
#  'this procedure',
#  'simple atheroma',
#  'left ventricular aneurysm',
#  'elev. chol.',
#  'simple atheroma',
#  'severe systolic htn',
#  'bisoprolol',
#  'mildly dilated',
#  'mchc',
#  'mild inferior hypokinesis',
#  'creams',
#  'any incisions',
#  'mild symmetric left ventricular hypertrophy',
#  'resting regional wall motion abnormalities',
#  'ventricular septal defect',
#  'mild regional left ventricular systolic dysfunction',
#  'powders',
#  'overall left ventricular systolic function',
#  'mildly depressed',
#  'vegetation',
#  'lotions',
#  'vegetations',
#  'color doppler',
#  'atrial septal defect',
#  'masses',
#  'oxycodone-acetaminophen',
#  'pain',
#  'face right nephrectomy',
#  '2d',
#  'scattered rales',
#  'potassium chloride',
#  'pre-op eval.',
#  'ranitidine hcl',
#  'mild mr',
#  'inferior hk',
#  'mass/thrombus',
#  'lisinopril',
#  'mild lae',
#  'rbc',
#  'echo',
#  'mild lvh',
#  'aspirin',
#  'thrombus',
#  'mcv',
#  'mildly dilated',
#  'propofol drips',
#  'blood',
#  'spontaneous echo contrast',
#  'chest tubes',
#  'phenylephrine',
#  'persistent pleural effusions',
#  'mch',
#  'hctz',
#  'vascular catheter tip',
#  'bibasilar minor atelectasis',
#  'pacing wires',
#  'foley',
#  'gentle diuresis',
#  'bilateral pleural effusions',
#  'metoprolol tartrate',
#  'hct',
#  'beta blockade',
#  'vomiting',
#  'asa',
#  'ck-mb',
#  'plavix',
#  'diaphoresis',
#  'ck',
#  'heparin drip',
#  'mchc',
#  'cpk',
#  'an ecg',
#  'new st depressions in v1-v4',
#  'ctropnt',
#  'substernal chest pain',
#  'blood',
#  'mch',
#  'ck-mb',
#  'nausea',
#  'rdw',
#  'glucose',
#  'her vitals',
#  'htn',
#  'ck',
#  'ekg',
#  'st depressions in v1-v4',
#  'hr',
#  'cpk',
#  'blood',
#  'bp',
#  'troponin',
#  'mb indx',
#  'ctropnt',
#  'nstemi',
#  'cpk',
#  'asa',
#  'coronary artery catheterization',
#  'ck-mb',
#  'nitro sl',
#  'her metoprolol dose',
#  'an echo',
#  'wall motion abnormalities',
#  'hr',
#  'her chest pain',
#  'morphine',
#  'atrial fibrillation',
#  'substernal chest pain',
#  'phos',
#  'her sbp',
#  'mcv',
#  'mg',
#  'hct',
#  'lisinopril',
#  'hgb',
#  'htn',
#  'rbc',
#  'wbc',
#  'lisinopril',
#  'chest pain',
#  'atorvastatin',
#  'metoprolol',
#  'labs',
#  'ctropnt',
#  'mb indx',
#  'nitro drip',
#  'macular degeneration',
#  'her afib',
#  'mild elevated wbc',
#  'r ankle fx',
#  'ua',
#  'coumadin',
#  'blindness',
#  'cardioversion',
#  'weight gain',
#  'hearing difficulty',
#  'shortness of breath',
#  'lipitor',
#  'bilateral crackles at bases and midlungs',
#  'cath',
#  'her new meds',
#  'leukocytosis-',
#  'htn',
#  'respiratory difficulty',
#  "lft 's",
#  'rr',
#  'supplemental o2',
#  'o2 sat',
#  'bp',
#  'mild pulm edema',
#  'her o2 sat',
#  'lasix',
#  't',
#  'hr',
#  'her bp',
#  'aspirin',
#  'anti-coagulation',
#  'plavix',
#  'metoprolol',
#  'hysterectomy',
#  'her chem 7',
#  'ekg',
#  'sinus brady',
#  'old lad and new st depressions in v1-v4',
#  'metoprolol',
#  'elevated jvp',
#  'artifical tears',
#  'docusate sodium',
#  'constipation',
#  'trace bilateral ankle edema',
#  'guaiac',
#  'senna',
#  'acute mi',
#  'pulmonary edema',
#  'diffuse opacities',
#  'bibasilar crackles',
#  'lisinopril',
#  'her cxr',
#  'cxr',
#  'murmur',
#  'tylenol',
#  'exam',
#  'rr',
#  'protonix',
#  'heparin gtt',
#  'a culture',
#  'afebrile',
#  'metoprolol',
#  'morphine',
#  'positive',
#  'few bacteria',
#  'nitro sl',
#  "wbc 's",
#  'asa',
#  'lasix',
#  'bactrim',
#  'clopidogrel',
#  'trace ankle edema bilaterally',
#  'aspirin',
#  'nad',
#  'masses',
#  'polyvinyl alcohol',
#  'hgb',
#  'pantoprazole',
#  'wbc',
#  'atorvastatin',
#  'rbc',
#  'acetaminophen',
#  'jvp',
#  'metoprolol tartrate',
#  'm/r/g',
#  'her hr',
#  'blind',
#  'lisinopril',
#  'lasix',
#  'shortness of breath',
#  'wheezing',
#  'nt',
#  'nd',
#  'crackles at base and mid-lungs bilaterally',
#  'indigestion',
#  'maalox',
#  'na',
#  'creat',
#  'lasix',
#  'weight gain',
#  'shortness of breath',
#  'urean',
#  'hco3',
#  'atrial fibrillation',
#  'cl',
#  'k',
#  'mchc',
#  'chest pain',
#  'mch',
#  'mcv',
#  'htn',
#  'hct',
#  'glucose',
#  'all medications',
#  'plt ct',
#  'heart rate',
#  'rdw',
#  'bp',
#  'rbbb',
#  'chest pain',
#  'st depressions in v1-v4',
#  'several new medications',
#  'q wave in i',
#  'shortness of breath',
#  'vomiting',
#  'st elevation in iii',
#  'nausea',
#  'avf',
#  'fevers',
#  'twi in iii',
#  'angap',
#  'ck',
#  'chills',
#  'cpk',
#  'o2 sat',
#  'sscp',
#  'troponin',
#  'ctropnt',
#  'ekg',
#  'lvh',
#  'further management',
#  'nstemi',
#  'la',
#  'lvef',
#  'sinus brady',
#  'echo',
#  'mb indx',
#  'regional wall motion abnormality',
#  'blood',
#  'cardiac enzymes',
#  'angap',
#  'calcium',
#  'hco3',
#  'ck',
#  'cxr',
#  'k',
#  'cl',
#  'the still mild pulmonary edema',
#  'creat',
#  'slight worsening',
#  'pneumothorax',
#  'na',
#  'urean',
#  'small right pleural effusion',
#  'plt ct',
#  'his respiratory distress',
#  'his state screen',
#  'prematurity',
#  'bradycardia',
#  'apnea',
#  'intravenous fluids',
#  'enteral feeds',
#  'pe-20',
#  'antibiotics',
#  'sepsis',
#  'caffeine',
#  'cmed examination',
#  'hearing test',
#  'influenza',
#  'additional oxygen',
#  'prematurity',
#  'low-flow nasal cannula',
#  'immunization',
#  'nystatin powder',
#  'an erythematous perianal rash',
#  'nasal prong cpap',
#  'apnea',
#  'chronic lung disease',
#  'caffeine therapy',
#  'bradycardic events',
#  'influenza vaccination',
#  'some apnea',
#  'nontender',
#  'chronic lung disease',
#  'feeds',
#  'bradycardic spells of prematurity',
#  'the neurological examination',
#  'a rebound bilirubin level',
#  'synagis rsv prophylaxis',
#  'his phototherapy',
#  'caffeine',
#  'nondistended',
#  'a single phototherapy',
#  'physiologic hyperbilirubinemia',
#  'tco2',
#  'vaginal bleeding',
#  'clunk',
#  'his most recent bilirubin',
#  '25 polys',
#  'bag mask ventilation',
#  'lesions',
#  'his admission complete blood count',
#  'bands',
#  'peak bili',
#  'spontaneous respiratory effort',
#  'rpr',
#  'hematocrit',
#  'the cardiovascular examination',
#  'murmurs',
#  'platelet count',
#  'cl',
#  'hepatitis b surface antigen',
#  'feeding immaturity',
#  '2+ femoral pulses',
#  'a white count',
#  'hepatosplenomegaly',
#  'increased blood pressure',
#  'hyperbilirubinemia',
#  'defects',
#  'k',
#  'antibiotics',
#  'magnesium sulfate',
#  'limp',
#  'fetal bradycardia',
#  'apgar scores',
#  'coarse bilaterally',
#  'last set of electrolytes',
#  'moderate retractions',
#  'betamethasone',
#  'na',
#  'the blood culture',
#  'proteinuria',
#  'rubella',
#  'mild to moderate respiratory distress',
#  'these pg feedings',
#  'fetal bradycardia',
#  's1',
#  'blood culture',
#  'his iv',
#  'a stat cesarean section',
#  'stat cesarean section',
#  'pe-20',
#  's2',
#  'masses',
#  'chills',
#  'mitochondrial myopathy',
#  'two transurethral resection of the prostate',
#  'chronic prostatitis',
#  'supraventricular tachycardia',
#  'turp',
#  'fevers',
#  'new and continuing nausea',
#  'procedure',
#  'vomiting',
#  'supraventricular tachycardia',
#  'pyridium',
#  'interstitial cystitis',
#  'a recent catheterization',
#  'coronary artery disease',
#  'plt count',
#  'cardiac monitoring',
#  'interstitial cystitis',
#  'tetracyclines',
#  'hgb',
#  'mcv',
#  'an over the counter stool softener',
#  'constipation',
#  'sulfonamides',
#  'pain medications',
#  'catheter',
#  'constipation',
#  'mchc',
#  'swollen',
#  ...]

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all texts. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those texts.

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=35, verbose=True)
topics, _ = topic_model.fit_transform(texts)
# Out:
# Batches:   0%|          | 0/517 [00:00<?, ?it/s]
# 2022-01-13 23:16:41,493 - BERTopic - Transformed documents to Embeddings
# 2022-01-13 23:17:13,460 - BERTopic - Reduced dimensionality with UMAP
# 2022-01-13 23:17:17,007 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                      Name
# 0     -1   4782       -1_cultures_weakness_copd_pulmonary
# 1      0    236                    0_scan_ct_mri_contrast
# 2      1    229           1_bowel_diarrhea_stools_urinary
# 3      2    226              2_dvt_prophylaxis_lymphs_lvh
# 4      3    172  3_carotid_stenosis_angioplasty_angiogram
# 5      4    167              4_fluid_volume_fluids_saline
# 6      5    150       5_reflexes_sleep_agitated_agitation
# 7      6    149       6_pain_trigeminal_control_analgesia
# 8      7    149       7_aortic_regurgitation_valve_mitral
# 9      8    146                        8_neuts_bs_nrb_fbs

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_nr = freq.iloc[0]["Topic"]  # We select a frequent topic
topic_model.get_topic(topic_nr)   # You can select a topic number as shown above
# Out:
# [('cultures', 0.007831482072993435),
#  ('weakness', 0.007452124208368343),
#  ('copd', 0.00725176907345469),
#  ('pulmonary', 0.007158068977883096),
#  ('physical', 0.007065120259498133),
#  ('ekg', 0.006936450306212081),
#  ('pericardial', 0.0067155095249536775),
#  ('hgb', 0.006601568572832218),
#  ('mch', 0.006601568572832218),
#  ('extremity', 0.0064627940838306265)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map.

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="86dfd129-9e08-441a-9b18-9cccec4abaeb" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86dfd129-9e08-441a-9b18-9cccec4abaeb")) {                    Plotly.newPlot(                        "86dfd129-9e08-441a-9b18-9cccec4abaeb",                        [{"customdata":[[0,"scan | ct | mri | contrast | imaging",236],[1,"bowel | diarrhea | stools | urinary | colonoscopy",229],[2,"dvt | prophylaxis | lymphs | lvh | pna",226],[3,"carotid | stenosis | angioplasty | angiogram | angina",172],[4,"fluid | volume | fluids | saline | intravenous",167],[5,"reflexes | sleep | agitated | agitation | fatigue",150],[6,"pain | trigeminal | control | analgesia | breakthrough",149],[7,"aortic | regurgitation | valve | mitral | atorvastatin",149],[8,"neuts | bs | nrb | fbs | atrovent",146],[9,"atelectasis | lobe | consolidation | opacities | consolidations",143],[10,"catheter | pacer | tracheostomy | catheterization | dialysis",133],[11,"surgery | surgical | care | tonsillectomy | preoperative",130],[12,"tumor | lesion | lesions | carcinoma | cancer",125],[13,"infection | infectious | bacteremia | corynebacterium | coli",122],[14,"cells | red | lymphadenopathy | packed | iodine",118],[15,"liver | enzymes | tests | hepatitis | cirrhosis",111],[16,"hemorrhage | hematoma | occipital | stroke | intracranial",111],[17,"cholangiopancreatography | endoscopic | biliary | retrograde | bile",111],[18,"respiratory | distress | sounds | breathing | bronchoscopy",105],[19,"ventricular | systolic | diastolic | dysfunction | function",105],[20,"delivery | cesarean | labor | vaginal | section",100],[21,"lactulose | fluticasone | flomax | lactate | flovent",100],[22,"anxiety | time | prothrombin | apparent | removal",99],[23,"lisinopril | gentamicin | cp | gentamycin | zestril",97],[24,"o2 | sat | ibuprofen | norvasc | requirement",94],[25,"chest | pain | substernal | discomfort | 1010",93],[26,"vomiting | auscultation | clubbing | passing | vomitting",92],[27,"hypertension | longstanding | hypertensive | portal | maternal",90],[28,"bleeding | bleed | gi | clot | clotting",89],[29,"vancomycin | ast | vasotec | astsgot | vanc",88],[30,"nystatin | diet | intake | swallow | poor",87],[31,"trazodone | zantac | ranitidine | hcl | pentamidine",86],[32,"urine | hematuria | output | dysuria | peep",85],[33,"hematocrit | alt | hemoptysis | altsgpt | alt33",85],[34,"abdominal | abdomen | pain | bloating | girth",85],[35,"blood | products | type | dye | load",84],[36,"pt | eval | ptx | atarax | alignment",82],[37,"shortness | breath | of | short | increased",81],[38,"symptoms | other | worrisome | depression | concerning",80],[39,"bun | protonix | creat | bid | peg",79],[40,"tube | feeds | nasogastric | tubes | feedings",78],[41,"hypotension | hyperlipidemia | hyperbilirubinemia | alkalosis | hypokalemia",77],[42,"xray | chest | portable | ct | ap",77],[43,"weight | obese | plt | discharge | gain",76],[44,"medications | medicine | all | medication | injections",76],[45,"albuterol | nebulizer | ipratropium | occupational | inhaler",76],[46,"coumadin | warfarin | dose | corgard | therapy",75],[47,"pulses | pulse | vital | signs | dorsalis",75],[48,"ns | arf | diovan | avandia | avr",75],[49,"rdw | urean | urea | uri | urobilngn",75],[50,"lasix | iv | intravenous | drip | gtt",74],[51,"fracture | fractures | rib | transverse | displaced",74],[52,"evaluation | fraction | ejection | further | systems",73],[53,"renal | insufficiency | kidney | nephropathy | nephrostomy",73],[54,"examination | exam | rectal | testing | admission",71],[55,"infarction | myocardial | cardiomyopathy | cardiomegaly | acute",71],[56,"drainage | bilirubin | drains | drain | direct",71],[57,"aspirin | entericcoated |  ...
